# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

from src.frontier import frontier_construction, frontier_plot
import numpy as np

# %%
frontier = frontier_construction(X=10000, T=1, N=10, sigma=0.3, eta=1e-6, gamma=1e-7, lambda_range=np.logspace(-8, -4, 100), n_sims=10000, S0=100)
print(frontier)
# Out:
#           lambda   mean_cost  variance_cost
# 0   1.000000e-08  100.548872   2.556689e+06
# 1   1.097499e-08  117.290312   2.592904e+06
# 2   1.204504e-08  120.184433   2.557035e+06
# 3   1.321941e-08   94.363989   2.523999e+06
# 4   1.450829e-08  105.857281   2.570182e+06
# ..           ...         ...            ...
# 95  6.892612e-05  142.902594   1.304688e+06
# 96  7.564633e-05  125.360967   1.213732e+06
# 97  8.302176e-05  137.596362   1.181148e+06
# 98  9.111628e-05  167.228670   1.099674e+06
# 99  1.000000e-04  163.471853   1.045650e+06
#
# [100 rows x 3 columns]

# %%
frontier_plot(frontier)

# %%
frontier = frontier_construction(X=10000, T=1, N=10, sigma=0.3, eta=1e-6, gamma=1e-7, lambda_range=np.logspace(-8, -4, 100), n_sims=10000, S0=100)
print(frontier)
# Out:
#           lambda   mean_cost  variance_cost
# 0   1.000000e-08  104.499744   2.676149e+06
# 1   1.097499e-08  104.499719   2.602867e+06
# 2   1.204504e-08  104.499692   2.572587e+06
# 3   1.321941e-08  104.499662   2.613656e+06
# 4   1.450829e-08  104.499630   2.601690e+06
# ..           ...         ...            ...
# 95  6.892612e-05  137.711059   1.298347e+06
# 96  7.564633e-05  141.973036   1.242396e+06
# 97  8.302176e-05  146.626309   1.181574e+06
# 98  9.111628e-05  151.683417   1.129766e+06
# 99  1.000000e-04  157.154705   1.040953e+06
#
# [100 rows x 3 columns]

# %%
frontier_plot(frontier)
