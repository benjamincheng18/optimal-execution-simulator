# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

from src.data_loader import fetch_raw_data, avg_volume, volatility
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tsm = fetch_raw_data(ticker="tsm", interval="5m", start="2026-06-29", end="2026-07-02")
tsm.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                           Close  Volume
# Datetime
# 2026-06-29 13:30:00+00:00  442.617493  811397
# 2026-06-29 13:35:00+00:00  441.345001  275113
# 2026-06-29 13:40:00+00:00  444.475006  280017
# 2026-06-29 13:45:00+00:00  442.109985  235705
# 2026-06-29 13:50:00+00:00  442.929993  245140

# %%
avg_vol = avg_volume(tsm)
print(avg_vol)
sigma = volatility(tsm, tau=0.1, interval="5m")
print(sigma)
# Out:
#                 volume
# 13:30:00  1.007673e+06
# 13:35:00  3.798317e+05
# 13:40:00  2.677057e+05
# 13:45:00  2.940043e+05
# 13:50:00  2.868067e+05
# ...                ...
# 19:35:00  1.391410e+05
# 19:40:00  1.827897e+05
# 19:45:00  2.236567e+05
# 19:50:00  3.178457e+05
# 19:55:00  9.776717e+05
#
# [78 rows x 1 columns]
# 0.009718759696599378
